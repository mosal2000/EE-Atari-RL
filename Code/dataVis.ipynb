# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path7 = r"7 Layers\\"
df17 = pd.read_csv(path7+r"Cone\\7L_Cone.csv")
df27 = pd.read_csv(path7+r"ConeInv\\7L_ConeInv.csv")
df37 = pd.read_csv(path7+r"HourG\\7L_HourG.csv")
df47 = pd.read_csv(path7+r"HourGInv\\7L_HourGInv.csv")
df57 = pd.read_csv(path7+r"Line\\7L_Line.csv")

path6 = r"6 Layers\\"
df16 = pd.read_csv(path6+r"Cone\\6L_Cone.csv")
df26 = pd.read_csv(path6+r"ConeInv\\6L_ConeInv.csv")
df36 = pd.read_csv(path6+r"HourG\\6L_HourG.csv")
# df46 = pd.read_csv(path6+r"HourGInv\\76_HourGInv.csv")
# df56 = pd.read_csv(path6+r"Line\\6L_Line.csv")

# %%
cols = ["loss", "mae", "mean_q", "mean_eps", "episode_reward", "nb_episode_steps", "nb_steps", "episode", "duration"]

tCol = 'mean_q'
tX = 'episode'

# 7 layers
x17 = df17[tX]
y17 = df17[tCol]

x27 = df27[tX]
y27 = df27[tCol]

x37 = df37[tX]
y37 = df37[tCol]

x47 = df47[tX]
y47 = df47[tCol]

x57 = df57[tX]
y57 = df57[tCol]

#6 layers
x16 = df16[tX]
y16 = df16[tCol]

x26 = df26[tX]
y26 = df26[tCol]

x36 = df36[tX]
y36 = df36[tCol]

# x46 = df46[tX]
# y46 = df46[tCol]

# x56 = df56[tX]
# y56 = df56[tCol]

alpha = 0.7
lw = 0.7
 
fig = plt.figure(figsize=(20,12))
ax = fig.add_axes([0,0,1,1])

ax.plot(x17,y17, alpha=alpha, label = "7 Cone", lw=lw)
ax.plot(x27,y27, alpha=alpha, label = "7 Cone Inv", lw=lw)
# ax.plot(x37,y37, alpha=alpha, label = "7 HourG", lw=lw)
# ax.plot(x47,y47, alpha=alpha, label = "7 HourG Inv", lw=lw)
# ax.plot(x57,y57, alpha=alpha, label = "7 Line", lw=lw)

ax.plot(x16,y16, alpha=alpha, label = "6 Cone", lw=lw)
ax.plot(x26,y26, alpha=alpha, label = "6 Cone Inv", lw=lw)
# ax.plot(x36,y36, alpha=alpha, label = "6 HourG", lw=lw)

ax.set_xlabel(tX)
ax.set_ylabel(tCol)
ax.legend(loc=0)
